# %%
# %%sql
# -- CREATE TABLE MLOps (workbook string, experiment string, model string)
# -- INSERT INTO MLOps VALUES ("THIS workbook", "Experiment 1", "model 1")
# -- SELECT * FROM MLOps WHERE workbook = "THIS workbook"
# INSERT INTO MLOps VALUES ("Demo Workbook", "XGBoost-Experiment1", "xgboost_iris")
# Out:
# StatementMeta(, d8050d6c-c4ac-462f-918c-d29891803741, 2, Finished, Available)
# <Spark SQL result set with 0 rows and 0 fields>
