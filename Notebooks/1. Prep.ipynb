# %% [markdown]
# # Table Creation
# Create a table to be use for Configuration

# %%
# %%sql
# CREATE TABLE MLOpsConfig (notebook string, experiment string, model string)
# Out:
# StatementMeta(, d8050d6c-c4ac-462f-918c-d29891803741, 2, Finished, Available)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# INSERT INTO MLOpsConfig VALUES ("2. Notebook_ Model Build", "XGBoost-Experiment1", "xgboost_iris")
# INSERT INTO MLOpsConfig VALUES ("3. Notebook_ Model Validation", "XGBoost-Experiment1", "xgboost_iris")
